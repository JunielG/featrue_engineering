# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
airbnb = pd.read_csv('AB_NYC_2019.csv')

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38821 entries, 0 to 48852
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              38821 non-null  int64
#  1   name                            38821 non-null  object
#  2   host_id                         38821 non-null  int64
#  3   host_name                       38821 non-null  object
#  4   neighbourhood_group             38821 non-null  object
#  5   neighbourhood                   38821 non-null  object
#  6   latitude                        38821 non-null  float64
#  7   longitude                       38821 non-null  float64
#  8   room_type                       38821 non-null  object
#  9   price                           38821 non-null  int64
#  10  minimum_nights                  38821 non-null  int64
#  11  number_of_reviews               38821 non-null  int64
# ...

# %%
airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
# 5        Chris           Manhattan   Murray Hill  40.74767  -73.97500
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
airbnb.isna().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
airbnb = airbnb.dropna(subset=['name', 'host_name'])

# %%
airbnb['last_review'] = pd.to_datetime(airbnb['last_review'])

# %%
airbnb['reviews_per_month'] = airbnb['reviews_per_month'].fillna(airbnb['reviews_per_month'].mode()[0])

# %%
airbnb = airbnb.dropna(subset=['last_review'])

# %%
airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
# 5        Chris           Manhattan   Murray Hill  40.74767  -73.97500
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#airbnb['room_type'].value_counts()

# %%
#groups = airbnb[['room_type', 'price', 'minimum_nights']]

# %%
#display(groups)

# %%
airbnb.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  3.882100e+04  3.882100e+04  38821.000000  38821.000000  38821.000000
# mean   1.810081e+07  6.424582e+07     40.728129    -73.951149    142.332526
# min    2.539000e+03  2.438000e+03     40.506410    -74.244420      0.000000
# 25%    8.721444e+06  7.029525e+06     40.688640    -73.982460     69.000000
# 50%    1.887286e+07  2.837092e+07     40.721710    -73.954810    101.000000
# 75%    2.756746e+07  1.018905e+08     40.762990    -73.935020    170.000000
# max    3.645581e+07  2.738417e+08     40.913060    -73.712990  10000.000000
# std    1.069372e+07  7.589752e+07      0.054991      0.046693    196.994756
#
#        minimum_nights  number_of_reviews                    last_review  \
# count    38821.000000       38821.000000                          38821
# mean         5.869220          29.290255  2018-10-04 07:23:47.072975872
# ...

# %%
airbnb.shape
# Out:
# (38821, 16)

# %% [markdown]
# ### Detecting Outliers

# %%
min_threshold, max_threshold = airbnb['price'].quantile([0.01, 0.999])
min_threshold, max_threshold
# Out:
# (30.0, 2000.0)

# %%
airbnb[airbnb['price'] < min_threshold]
# Out:
#              id                                             name    host_id  \
# 957      375249                  Enjoy Staten Island Hospitality    1887999
# 2675    1428154              Central, Peaceful Semi-Private Room    5912572
# 3020    1767037               Small Cozy Room Wifi & AC near JFK    9284163
# 3918    2431607                    Bright, Airy Room Share for 2    4973668
# 4647    3258197     Large 1br Duplex in Heart of Upper East Side   16477306
# ...         ...                                              ...        ...
# 46894  35481807  Male Shared room 1 bed in the bedroom long term  179478172
# 47130  35606165          Luggage storage only No Beds Available.  267872829
# 47218  35642891                       Beautiful room in Bushwick  268138154
# 48126  36101190                                 Flushing Hideout   30839692
# 48486  36280646                     Cable and wfi, L/G included.  272872092
#
# ...

# %%
airbnb[airbnb['price'] > max_threshold]
# Out:
#              id                                               name    host_id  \
# 2018     893413         Architecturally Stunning Former Synagogue!    4751930
# 2698    1448703                Beautiful 1 Bedroom in Nolita/Soho      213266
# 3537    2110145                 UWS 1BR w/backyard + block from CP    2151325
# 4127    2659183                   Luxury 5BR Townhouse, Upper East    5907325
# 4345    2919330                   NearWilliamsburg bridge 11211 BK   14908606
# 4376    2952861                               Photography Location    1177497
# 4377    2953058                                      Film Location    1177497
# 6530    4737930                                 Spanish Harlem Apt    1235070
# 6620    4777903                                       SOHO GALLERY    1581845
# 9151    7003697                Furnished room in Astoria apartment   20582832
# 12342   9528920                Quiet, Clean, Lit @ LES & Chinatown    3906464
# ...

# %%
df = airbnb[(airbnb['price'] < max_threshold) & (airbnb['price'] > min_threshold)]

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
# 5        Chris           Manhattan   Murray Hill  40.74767  -73.97500
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.shape
# Out:
# (38262, 16)

# %%
airbnb['price'].describe()
# Out:
# count    38821.000000
# mean       142.332526
# std        196.994756
# min          0.000000
# 25%         69.000000
# 50%        101.000000
# 75%        170.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
df['price'].describe()
# Out:
# count    38262.000000
# mean       139.097355
# std        118.162195
# min         31.000000
# 25%         70.000000
# 50%        105.000000
# 75%        170.000000
# max       1999.000000
# Name: price, dtype: float64
